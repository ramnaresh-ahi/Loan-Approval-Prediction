# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
# Install scikit-learn version 1.5.1 using pip
# !pip install scikit-learn==1.5.1
# Out:
# Requirement already satisfied: scikit-learn==1.5.1 in c:\users\hp\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\hp\anaconda3\lib\site-packages (from scikit-learn==1.5.1) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\hp\anaconda3\lib\site-packages (from scikit-learn==1.5.1) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\hp\anaconda3\lib\site-packages (from scikit-learn==1.5.1) (1.2.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\hp\anaconda3\lib\site-packages (from scikit-learn==1.5.1) (3.5.0)

# %%
df = pd.read_csv("loan.csv")

# %%
df
# Out:
#     age  gender    occupation education_level marital_status  income  \
# 0    32    Male      Engineer      Bachelor's        Married   85000
# 1    45  Female       Teacher        Master's         Single   62000
# 2    28    Male       Student     High School         Single   25000
# 3    51  Female       Manager      Bachelor's        Married  105000
# 4    36    Male    Accountant      Bachelor's        Married   75000
# ..  ...     ...           ...             ...            ...     ...
# 56   39    Male     Architect        Master's        Married  100000
# 57   25  Female  Receptionist     High School         Single   32000
# 58   43    Male        Banker      Bachelor's        Married   95000
# 59   30  Female        Writer        Master's         Single   55000
# 60   38    Male          Chef     Associate's        Married   65000
#
#     credit_score loan_status
# 0            720    Approved
# 1            680    Approved
# 2            590      Denied
# 3            780    Approved
# 4            710    Approved
# ..           ...         ...
# 56           770    Approved
# 57           570      Denied
# 58           760    Approved
# 59           650    Approved
# 60           700    Approved
#
# [61 rows x 8 columns]

# %%
df.describe()
# Out:
#              age         income  credit_score
# count  61.000000      61.000000     61.000000
# mean   37.081967   78983.606557    709.836066
# std     8.424755   33772.025802     72.674888
# min    24.000000   25000.000000    560.000000
# 25%    30.000000   52000.000000    650.000000
# 50%    36.000000   78000.000000    720.000000
# 75%    43.000000   98000.000000    770.000000
# max    55.000000  180000.000000    830.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              61 non-null     int64
#  1   gender           61 non-null     object
#  2   occupation       61 non-null     object
#  3   education_level  61 non-null     object
#  4   marital_status   61 non-null     object
#  5   income           61 non-null     int64
#  6   credit_score     61 non-null     int64
#  7   loan_status      61 non-null     object
# dtypes: int64(3), object(5)
# memory usage: 3.9+ KB

# %%
df["gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df["occupation"].unique()
# Out:
# array(['Engineer', 'Teacher', 'Student', 'Manager', 'Accountant', 'Nurse',
#        'Lawyer', 'Artist', 'IT', 'Doctor', 'Consultant', 'Analyst',
#        'Salesman', 'Marketing', 'Architect', 'Designer', 'Pharmacist',
#        'Researcher', 'Professor', 'Pilot', 'Receptionist', 'Banker',
#        'Writer', 'Chef', 'Veterinarian', 'Sales', 'HR', 'Electrician',
#        'Realtor', 'Photographer', 'Editor', 'Programmer', 'Dentist',
#        'Musician', 'Psychologist', 'Server', 'Software', 'Stylist'],
#       dtype=object)

# %%
df["education_level"].unique()
# Out:
# array(["Bachelor's", "Master's", 'High School', "Associate's", 'Doctoral'],
#       dtype=object)

# %%
df["marital_status"].unique()
# Out:
# array(['Married', 'Single'], dtype=object)

# %%
df["loan_status"].unique()
# Out:
# array(['Approved', 'Denied'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
# df["occupation_encoder"] = le.fit_transform(df["occupation"])
df["occupation_encoder"] = le.fit_transform(df["occupation"])
df["education_encoder"] = le.fit_transform(df["education_level"])
df["marital_encoder"] = le.fit_transform(df["marital_status"])
df["loan_encoder"] = le.fit_transform(df["loan_status"])

# %%
df
# Out:
#     age  gender    occupation education_level marital_status  income  \
# 0    32    Male      Engineer      Bachelor's        Married   85000
# 1    45  Female       Teacher        Master's         Single   62000
# 2    28    Male       Student     High School         Single   25000
# 3    51  Female       Manager      Bachelor's        Married  105000
# 4    36    Male    Accountant      Bachelor's        Married   75000
# ..  ...     ...           ...             ...            ...     ...
# 56   39    Male     Architect        Master's        Married  100000
# 57   25  Female  Receptionist     High School         Single   32000
# 58   43    Male        Banker      Bachelor's        Married   95000
# 59   30  Female        Writer        Master's         Single   55000
# 60   38    Male          Chef     Associate's        Married   65000
#
#     credit_score loan_status  occupation_encoder  education_encoder  \
# 0            720    Approved                  12                  1
# 1            680    Approved                  35                  4
# 2            590      Denied                  33                  3
# 3            780    Approved                  16                  1
# 4            710    Approved                   0                  1
# ..           ...         ...                 ...                ...
# 56           770    Approved                   2                  4
# 57           570      Denied                  27                  3
# 58           760    Approved                   4                  1
# 59           650    Approved                  37                  4
# 60           700    Approved                   5                  0
#
#     marital_encoder  loan_encoder
# 0                 0             0
# 1                 1             0
# 2                 1             1
# 3                 0             0
# 4                 0             0
# ..              ...           ...
# 56                0             0
# 57                1             1
# 58                0             0
# 59                1             0
# 60                0             0
#
# [61 rows x 12 columns]

# %%
df
# Out:
#     age  gender    occupation education_level marital_status  income  \
# 0    32    Male      Engineer      Bachelor's        Married   85000
# 1    45  Female       Teacher        Master's         Single   62000
# 2    28    Male       Student     High School         Single   25000
# 3    51  Female       Manager      Bachelor's        Married  105000
# 4    36    Male    Accountant      Bachelor's        Married   75000
# ..  ...     ...           ...             ...            ...     ...
# 56   39    Male     Architect        Master's        Married  100000
# 57   25  Female  Receptionist     High School         Single   32000
# 58   43    Male        Banker      Bachelor's        Married   95000
# 59   30  Female        Writer        Master's         Single   55000
# 60   38    Male          Chef     Associate's        Married   65000
#
#     credit_score loan_status  occupation_encoder  education_encoder  \
# 0            720    Approved                  12                  1
# 1            680    Approved                  35                  4
# 2            590      Denied                  33                  3
# 3            780    Approved                  16                  1
# 4            710    Approved                   0                  1
# ..           ...         ...                 ...                ...
# 56           770    Approved                   2                  4
# 57           570      Denied                  27                  3
# 58           760    Approved                   4                  1
# 59           650    Approved                  37                  4
# 60           700    Approved                   5                  0
#
#     marital_encoder  loan_encoder
# 0                 0             0
# 1                 1             0
# 2                 1             1
# 3                 0             0
# 4                 0             0
# ..              ...           ...
# 56                0             0
# 57                1             1
# 58                0             0
# 59                1             0
# 60                0             0
#
# [61 rows x 12 columns]

# %%
df.drop(columns=["occupation","education_level","marital_status","loan_status"],inplace = True)

# %%
df
# Out:
#     age  gender  income  credit_score  occupation_encoder  education_encoder  \
# 0    32    Male   85000           720                  12                  1
# 1    45  Female   62000           680                  35                  4
# 2    28    Male   25000           590                  33                  3
# 3    51  Female  105000           780                  16                  1
# 4    36    Male   75000           710                   0                  1
# ..  ...     ...     ...           ...                 ...                ...
# 56   39    Male  100000           770                   2                  4
# 57   25  Female   32000           570                  27                  3
# 58   43    Male   95000           760                   4                  1
# 59   30  Female   55000           650                  37                  4
# 60   38    Male   65000           700                   5                  0
#
#     marital_encoder  loan_encoder
# 0                 0             0
# 1                 1             0
# 2                 1             1
# 3                 0             0
# 4                 0             0
# ..              ...           ...
# 56                0             0
# 57                1             1
# 58                0             0
# 59                1             0
# 60                0             0
#
# [61 rows x 8 columns]

# %%
df["gender_encoder"] = le.fit_transform(df["gender"])

# %%
df
# Out:
#     age  gender  income  credit_score  occupation_encoder  education_encoder  \
# 0    32    Male   85000           720                  12                  1
# 1    45  Female   62000           680                  35                  4
# 2    28    Male   25000           590                  33                  3
# 3    51  Female  105000           780                  16                  1
# 4    36    Male   75000           710                   0                  1
# ..  ...     ...     ...           ...                 ...                ...
# 56   39    Male  100000           770                   2                  4
# 57   25  Female   32000           570                  27                  3
# 58   43    Male   95000           760                   4                  1
# 59   30  Female   55000           650                  37                  4
# 60   38    Male   65000           700                   5                  0
#
#     marital_encoder  loan_encoder  gender_encoder
# 0                 0             0               1
# 1                 1             0               0
# 2                 1             1               1
# 3                 0             0               0
# 4                 0             0               1
# ..              ...           ...             ...
# 56                0             0               1
# 57                1             1               0
# 58                0             0               1
# 59                1             0               0
# 60                0             0               1
#
# [61 rows x 9 columns]

# %%
df.drop(columns = ["gender"], inplace = True)

# %%
df
# Out:
#     age  income  credit_score  occupation_encoder  education_encoder  \
# 0    32   85000           720                  12                  1
# 1    45   62000           680                  35                  4
# 2    28   25000           590                  33                  3
# 3    51  105000           780                  16                  1
# 4    36   75000           710                   0                  1
# ..  ...     ...           ...                 ...                ...
# 56   39  100000           770                   2                  4
# 57   25   32000           570                  27                  3
# 58   43   95000           760                   4                  1
# 59   30   55000           650                  37                  4
# 60   38   65000           700                   5                  0
#
#     marital_encoder  loan_encoder  gender_encoder
# 0                 0             0               1
# 1                 1             0               0
# 2                 1             1               1
# 3                 0             0               0
# 4                 0             0               1
# ..              ...           ...             ...
# 56                0             0               1
# 57                1             1               0
# 58                0             0               1
# 59                1             0               0
# 60                0             0               1
#
# [61 rows x 8 columns]

# %%
num = df.select_dtypes(include = ("int64","float64")).columns
for i in num:
    print(f"columns : {i}")
    print(df[i].describe())
    print()
# Out:
# columns : age
# count    61.000000
# mean     37.081967
# std       8.424755
# min      24.000000
# 25%      30.000000
# 50%      36.000000
# 75%      43.000000
# max      55.000000
# Name: age, dtype: float64
#
# columns : income
# count        61.000000
# mean      78983.606557
# std       33772.025802
# min       25000.000000
# 25%       52000.000000
# 50%       78000.000000
# 75%       98000.000000
# max      180000.000000
# Name: income, dtype: float64
#
# columns : credit_score
# count     61.000000
# mean     709.836066
# std       72.674888
# min      560.000000
# 25%      650.000000
# 50%      720.000000
# 75%      770.000000
# max      830.000000
# Name: credit_score, dtype: float64

# %%
df
# Out:
#     age  income  credit_score  occupation_encoder  education_encoder  \
# 0    32   85000           720                  12                  1
# 1    45   62000           680                  35                  4
# 2    28   25000           590                  33                  3
# 3    51  105000           780                  16                  1
# 4    36   75000           710                   0                  1
# ..  ...     ...           ...                 ...                ...
# 56   39  100000           770                   2                  4
# 57   25   32000           570                  27                  3
# 58   43   95000           760                   4                  1
# 59   30   55000           650                  37                  4
# 60   38   65000           700                   5                  0
#
#     marital_encoder  loan_encoder  gender_encoder
# 0                 0             0               1
# 1                 1             0               0
# 2                 1             1               1
# 3                 0             0               0
# 4                 0             0               1
# ..              ...           ...             ...
# 56                0             0               1
# 57                1             1               0
# 58                0             0               1
# 59                1             0               0
# 60                0             0               1
#
# [61 rows x 8 columns]

# %%
corr_matrix = df.corr()

# %%
corr_matrix
# Out:
#                          age    income  credit_score  occupation_encoder  \
# age                 1.000000  0.743184      0.806042           -0.236898
# income              0.743184  1.000000      0.937983           -0.342652
# credit_score        0.806042  0.937983      1.000000           -0.347896
# occupation_encoder -0.236898 -0.342652     -0.347896            1.000000
# education_encoder   0.197880  0.164035      0.149835            0.109864
# marital_encoder    -0.746899 -0.752035     -0.845532            0.397308
# loan_encoder       -0.648135 -0.699577     -0.820765            0.271510
# gender_encoder     -0.049218  0.051406      0.111500           -0.252175
#
#                     education_encoder  marital_encoder  loan_encoder  \
# age                          0.197880        -0.746899     -0.648135
# income                       0.164035        -0.752035     -0.699577
# credit_score                 0.149835        -0.845532     -0.820765
# occupation_encoder           0.109864         0.397308      0.271510
# education_encoder            1.000000        -0.043876     -0.232458
# marital_encoder             -0.043876         1.000000      0.740370
# loan_encoder                -0.232458         0.740370      1.000000
# gender_encoder              -0.024387        -0.281703     -0.233413
#
#                     gender_encoder
# age                      -0.049218
# income                    0.051406
# credit_score              0.111500
# occupation_encoder       -0.252175
# education_encoder        -0.024387
# marital_encoder          -0.281703
# loan_encoder             -0.233413
# gender_encoder            1.000000

# %%
plt.figure(figsize = (20,8))
sns.heatmap(corr_matrix, annot = True, cmap = "coolwarm")
# Out:
# <Axes: >

# %%
df
# Out:
#     age  income  credit_score  occupation_encoder  education_encoder  \
# 0    32   85000           720                  12                  1
# 1    45   62000           680                  35                  4
# 2    28   25000           590                  33                  3
# 3    51  105000           780                  16                  1
# 4    36   75000           710                   0                  1
# ..  ...     ...           ...                 ...                ...
# 56   39  100000           770                   2                  4
# 57   25   32000           570                  27                  3
# 58   43   95000           760                   4                  1
# 59   30   55000           650                  37                  4
# 60   38   65000           700                   5                  0
#
#     marital_encoder  loan_encoder  gender_encoder
# 0                 0             0               1
# 1                 1             0               0
# 2                 1             1               1
# 3                 0             0               0
# 4                 0             0               1
# ..              ...           ...             ...
# 56                0             0               1
# 57                1             1               0
# 58                0             0               1
# 59                1             0               0
# 60                0             0               1
#
# [61 rows x 8 columns]

# %%
plt.figure()
sns.boxplot(x="education_encoder", y="loan_encoder",data=df)
# Out:
# <Axes: xlabel='education_encoder', ylabel='loan_encoder'>

# %%
plt.figure(figsize = (10,5))
sns.boxplot(x="occupation_encoder", y="loan_encoder",data=df)
# Out:
# <Axes: xlabel='occupation_encoder', ylabel='loan_encoder'>

# %%
plt.figure()
sns.boxplot(x="gender_encoder", y="loan_encoder",data=df)
# Out:
# <Axes: xlabel='gender_encoder', ylabel='loan_encoder'>

# %%
plt.figure(figsize = (10,8))
sns.boxplot(x="age", y="loan_encoder",data=df)
# Out:
# <Axes: xlabel='age', ylabel='loan_encoder'>

# %%
plt.figure(figsize = (10,8))
sns.boxplot(x="income", y="loan_encoder",data=df)
# Out:
# <Axes: xlabel='income', ylabel='loan_encoder'>

# %%
plt.figure(figsize = (10,8))
sns.boxplot(x="credit_score", y="loan_encoder",data=df)
# Out:
# <Axes: xlabel='credit_score', ylabel='loan_encoder'>

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('loan_encoder',axis=1)
y = df['loan_encoder']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score

# %%
# Initialize the model
model = LogisticRegression()

# Train the model
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Make predictions on the test data
y_pred = model.predict(X_test)

# %%
# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')
# Out:
# Accuracy: 1.00

# %%
# Generate a precision score
ps = precision_score(y_test, y_pred)
print('precision_score:')
print(ps)
# Out:
# precision_score:
# 1.0

# %%
# Generate a recall_score
rc = recall_score(y_test, y_pred)
print('recall_score:')
print(rc)
# Out:
# recall_score:
# 1.0

# %%
pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\hp\anaconda3\lib\site-packages (1.2.0)Note: you may need to restart the kernel to use updated packages.

# %%
import joblib

# %%
joblib.dump(model,'model.joblib')
# Out:
# ['model.joblib']
